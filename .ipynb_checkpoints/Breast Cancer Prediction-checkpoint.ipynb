# %% [markdown]
# ## Installing the dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import pickle

# %% [markdown]
# ## Analysing and visualising the dataset

# %%
dataset = pd.read_csv('breast_cancer.csv')

# %%
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# from the above cell, we can say that the 32nd column is empty, lets check
dataset['Unnamed: 32'].unique()
# Out:
# array([nan])

# %%
# since the column is empty, lets remove it and the id column from dataset
dataset = dataset.drop(columns = ['id', 'Unnamed: 32'], axis = 1)

# %%
# statistics of the dataset
dataset.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# ### Mapping the column diagnosis as
# 0 => Benign
#
# 1 => Malignant

# %%
dataset['diagnosis'] = dataset['diagnosis'].map({'M':1, 'B':0})

# %%
# Check the correlation between the features
plt.figure(figsize=(20, 20))
sns.heatmap(dataset.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# value counts of diagnosis
dataset['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocessing and splitting the dataset

# %%
# splitting dataset into features and target
X = dataset.drop('diagnosis', axis = 1)
Y = dataset['diagnosis']

# %%
# scaling the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
print(X)
# Out:
# [[ 1.09706398 -2.07333501  1.26993369 ...  2.29607613  2.75062224
#    1.93701461]
#  [ 1.82982061 -0.35363241  1.68595471 ...  1.0870843  -0.24388967
#    0.28118999]
#  [ 1.57988811  0.45618695  1.56650313 ...  1.95500035  1.152255
#    0.20139121]
#  ...
#  [ 0.70228425  2.0455738   0.67267578 ...  0.41406869 -1.10454895
#   -0.31840916]
#  [ 1.83834103  2.33645719  1.98252415 ...  2.28998549  1.91908301
#    2.21963528]
#  [-1.80840125  1.22179204 -1.81438851 ... -1.74506282 -0.04813821
#   -0.75120669]]

# %%
X.shape
# Out:
# (569, 30)

# %%
# splitting the dataset into training and testing
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 3, stratify = Y)

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Defining the hyperparameters
param_grid = {
    'solver': ['newton-cg', 'liblinear'],
    'penalty': ['l2'],
    'C': [100, 10, 1.0, 0.1, 0.01],
    'max_iter': [100, 200, 300]
}
# Creating a LogisticRegression object
lr_model = LogisticRegression(random_state = 3)
# Setting up the grid search
grid_search_cv = GridSearchCV(estimator = lr_model, param_grid = param_grid, cv = 5)
# Fitting the grid search to the data
grid_search_cv.fit(X_train, Y_train)
# Printing the best hyper parameters
best_parameters = grid_search_cv.best_params_
print(f'The best hyper parameters : {best_parameters}')
# Selecting the best model
best_lr_model = grid_search_cv.best_estimator_
# Out:
# The best hyper parameters : {'C': 1.0, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}

# %% [markdown]
# ## Model Evaluation

# %%
# accuracy on training data
X_train_pred = best_lr_model.predict(X_train)
train_data_accuracy = accuracy_score(X_train_pred, Y_train)
print("The accuracy on training data is : ", train_data_accuracy)
# Out:
# The accuracy on training data is :  0.9868131868131869

# %%
# accuracy on test data
X_test_pred = best_lr_model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_pred, Y_test)
print("The accuracy on test data is : ", test_data_accuracy)
# Out:
# The accuracy on test data is :  0.9912280701754386

# %%
# Printing the classification report
print(classification_report(Y_test, X_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        72
#            1       1.00      0.98      0.99        42
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114

# %%
# Saving the model
pickle.dump(best_lr_model, open('cancer_model.pkl', 'wb'))
